# %%
from subhalos import *

plt.rc('font', **{'family':'sans-serif','size':15})
plt.rc('text', usetex=False)
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)
plt.rcParams['xtick.major.size'] = 5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.size'] = 2
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.size'] = 5
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.size'] = 2
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.pad'] = 8
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True

# %%
M0=1e12                        
N_ma=500                        
zmax=7                          
logmamin=-6                 
redshift=0

# %%
ma200_1, rs_a_1, rhos_a_1, m0_1, rs0_1, rhos0_1, ct0_1, weight_1, survive_1, zacc1 \
    = rs_rhos_calc(M0=M0,logmamin=logmamin,logmamax=11,N_ma=N_ma, zmax=zmax,dz=0.008,Namodel=2)

ma200_1  *= Msolar
m0_1     *= Msolar
rs_a_1   *= kpc
rs0_1    *= kpc
rhos_a_1 *= Msolar/pc**3
rhos0_1  *= Msolar/pc**3

rpeak_1 = 2.163*rs_a_1
rmax_1  = 2.163*rs0_1
Vpeak_1 = np.sqrt(4.*np.pi*G*rhos_a_1/4.625)*rs_a_1
Vmax_1  = np.sqrt(4.*np.pi*G*rhos0_1/4.625)*rs0_1
# Out:
# /home/tsexos/jupyter/environment/Lefteris_subhalos/CDM_substructure_models_final/Final_Comparison/Redshift/dz/dz_Yang_3 (copy)/subhalos.py:225: RuntimeWarning: divide by zero encountered in power
#   normB=pow(2*np.pi,-0.5)*delca*0.57*pow(delca/np.sqrt(sM),-0.01)*(2./(1.-0.38))*pow(sM,-0.38/2.)*pow(xmin,0.5*(0.38-1.))*special.hyp2f1(0.5*(1-0.38),-0.38/2.,0.5*(3.-0.38),-sM/xmin)
# /home/tsexos/jupyter/environment/Lefteris_subhalos/CDM_substructure_models_final/Final_Comparison/Redshift/dz/dz_Yang_3 (copy)/subhalos.py:225: RuntimeWarning: divide by zero encountered in true_divide
#   normB=pow(2*np.pi,-0.5)*delca*0.57*pow(delca/np.sqrt(sM),-0.01)*(2./(1.-0.38))*pow(sM,-0.38/2.)*pow(xmin,0.5*(0.38-1.))*special.hyp2f1(0.5*(1-0.38),-0.38/2.,0.5*(3.-0.38),-sM/xmin)
# /home/tsexos/jupyter/environment/Lefteris_subhalos/CDM_substructure_models_final/Final_Comparison/Redshift/dz/dz_Yang_3 (copy)/subhalos.py:163: RuntimeWarning: invalid value encountered in power
# ...

# %%
ma200_2, rs_a_2, rhos_a_2, m0_2, rs0_2, rhos0_2, ct0_2, weight_2, survive_2, zacc2 \
    = rs_rhos_calc(M0=M0,logmamin=logmamin,logmamax=11,N_ma=N_ma, zmax=zmax,dz=0.01,Namodel=2)

ma200_2  *= Msolar
m0_2     *= Msolar
rs_a_2   *= kpc
rs0_2    *= kpc
rhos_a_2 *= Msolar/pc**3
rhos0_2  *= Msolar/pc**3

rpeak_2 = 2.163*rs_a_2
rmax_2  = 2.163*rs0_2
Vpeak_2 = np.sqrt(4.*np.pi*G*rhos_a_2/4.625)*rs_a_2
Vmax_2  = np.sqrt(4.*np.pi*G*rhos0_2/4.625)*rs0_2

# %%
ma200_3, rs_a_3, rhos_a_3, m0_3, rs0_3, rhos0_3, ct0_3, weight_3, survive_3, zacc3  \
    = rs_rhos_calc(M0=M0,logmamin=logmamin,logmamax=11,N_ma=N_ma, zmax=zmax,dz=0.05,Namodel=2)

ma200_3  *= Msolar
m0_3     *= Msolar
rs_a_3   *= kpc
rs0_3    *= kpc
rhos_a_3 *= Msolar/pc**3
rhos0_3  *= Msolar/pc**3

rpeak_3 = 2.163*rs_a_3
rmax_3  = 2.163*rs0_3
Vpeak_3 = np.sqrt(4.*np.pi*G*rhos_a_3/4.625)*rs_a_3
Vmax_3  = np.sqrt(4.*np.pi*G*rhos0_3/4.625)*rs0_3

# %%
ma200_4, rs_a_4, rhos_a_4, m0_4, rs0_4, rhos0_4, ct0_4, weight_4, survive_4, zacc4  \
    = rs_rhos_calc(M0=M0,logmamin=logmamin,logmamax=11,N_ma=N_ma, zmax=zmax,dz=0.1,Namodel=2)

ma200_4  *= Msolar
m0_4     *= Msolar
rs_a_4   *= kpc
rs0_4    *= kpc
rhos_a_4 *= Msolar/pc**3
rhos0_4  *= Msolar/pc**3

rpeak_4 = 2.163*rs_a_4
rmax_4  = 2.163*rs0_4
Vpeak_4 = np.sqrt(4.*np.pi*G*rhos_a_4/4.625)*rs_a_4
Vmax_4  = np.sqrt(4.*np.pi*G*rhos0_4/4.625)*rs0_4

# %%
ma200_5, rs_a_5, rhos_a_5, m0_5, rs0_5, rhos0_5, ct0_5, weight_5, survive_5, zacc5  \
    = rs_rhos_calc(M0=M0,logmamin=logmamin,logmamax=11,N_ma=N_ma, zmax=zmax,dz=0.3,Namodel=2)

ma200_5  *= Msolar
m0_5     *= Msolar
rs_a_5   *= kpc
rs0_5    *= kpc
rhos_a_5 *= Msolar/pc**3
rhos0_5  *= Msolar/pc**3

rpeak_5 = 2.163*rs_a_5
rmax_5  = 2.163*rs0_5
Vpeak_5 = np.sqrt(4.*np.pi*G*rhos_a_5/4.625)*rs_a_5
Vmax_5  = np.sqrt(4.*np.pi*G*rhos0_5/4.625)*rs0_5

# %%
ma200_6, rs_a_6, rhos_a_6, m0_6, rs0_6, rhos0_6, ct0_6, weight_6, survive_6, zacc6  \
    = rs_rhos_calc(M0=M0,logmamin=logmamin,logmamax=11,N_ma=N_ma, zmax=zmax,dz=0.7,Namodel=2)

ma200_6  *= Msolar
m0_6     *= Msolar
rs_a_6   *= kpc
rs0_6    *= kpc
rhos_a_6 *= Msolar/pc**3
rhos0_6  *= Msolar/pc**3

rpeak_6 = 2.163*rs_a_6
rmax_6  = 2.163*rs0_6
Vpeak_6 = np.sqrt(4.*np.pi*G*rhos_a_6/4.625)*rs_a_6
Vmax_6  = np.sqrt(4.*np.pi*G*rhos0_6/4.625)*rs0_6

# %%
ma200_7, rs_a_7, rhos_a_7, m0_7, rs0_7, rhos0_7, ct0_7, weight_7, survive_7, zacc7 \
    = rs_rhos_calc(M0=M0,logmamin=logmamin,logmamax=11,N_ma=N_ma, zmax=zmax,dz=1.2,Namodel=2)

ma200_7  *= Msolar
m0_7     *= Msolar
rs_a_7   *= kpc
rs0_7    *= kpc
rhos_a_7 *= Msolar/pc**3
rhos0_7  *= Msolar/pc**3

rpeak_7 = 2.163*rs_a_7
rmax_7  = 2.163*rs0_7
Vpeak_7 = np.sqrt(4.*np.pi*G*rhos_a_7/4.625)*rs_a_7
Vmax_7  = np.sqrt(4.*np.pi*G*rhos0_7/4.625)*rs0_7

# %%
ma200_8, rs_a_8, rhos_a_8, m0_8, rs0_8, rhos0_8, ct0_8, weight_8, survive_8, zacc8 \
    = rs_rhos_calc(M0=M0,logmamin=logmamin,logmamax=11,N_ma=N_ma, zmax=zmax,dz=1.7,Namodel=2)

ma200_8  *= Msolar
m0_8     *= Msolar
rs_a_8   *= kpc
rs0_8    *= kpc
rhos_a_8 *= Msolar/pc**3
rhos0_8  *= Msolar/pc**3

rpeak_8 = 2.163*rs_a_8
rmax_8  = 2.163*rs0_8
Vpeak_8 = np.sqrt(4.*np.pi*G*rhos_a_8/4.625)*rs_a_8
Vmax_8  = np.sqrt(4.*np.pi*G*rhos0_8/4.625)*rs0_8

# %% [markdown]
# ## Satellites Number, Mass Function, Mass Fraction and Slope Comparison:

# %%
def sat_vth(Vmax,Vpeak,Vpeak_max,weight):
    N,x_edges = np.histogram(Vmax[Vpeak>Vpeak_max*km/s]/(km/s),weights=weight[Vpeak>Vpeak_max*km/s],bins=10000)
    x = (x_edges[1:]+x_edges[:-1])/2.
    Ncum = np.cumsum(N)
    Ncum = Ncum[-1]-Ncum

    return Ncum[0], x, Ncum

def m2dndm(m0,weight,zacc=None,z_min=0,z_max=7):
    
    if (zacc is None)==False:
        m0=m0[(zacc>z_min)*(zacc<=z_max)]
        weight=weight[(zacc>z_min)*(zacc<=z_max)]
        
    N,lnm_edges = np.histogram(np.log(m0/Msolar),weights=weight)#,bins=100)
    lnm = (lnm_edges[1:]+lnm_edges[:-1])/2.
    dlnm = lnm_edges[1:]-lnm_edges[:-1]

    m = np.exp(lnm)
    dNdlnm = N/dlnm

    dNdm   = dNdlnm/m
    

    return m, m**2*dNdm

m_1,m2dndm_1 = m2dndm(m0_1,weight_1)
m_2,m2dndm_2 = m2dndm(m0_2,weight_2)
m_3,m2dndm_3 = m2dndm(m0_3,weight_3)
m_4,m2dndm_4 = m2dndm(m0_4,weight_4)
m_5,m2dndm_5 = m2dndm(m0_5,weight_5)
m_6,m2dndm_6 = m2dndm(m0_6,weight_6)
m_7,m2dndm_7 = m2dndm(m0_7,weight_7)
m_8,m2dndm_8 = m2dndm(m0_8,weight_8)

# %%
Vpeak_max = 18 # km/s
cm       = 1.
km       = 1.e5*cm
s        = 1.

Nsat_tot_1, V_1, Nsh_1 = sat_vth(Vmax_1,Vpeak_1,Vpeak_max,weight_1)
Nsat_tot_2, V_2, Nsh_2 = sat_vth(Vmax_2,Vpeak_2,Vpeak_max,weight_2)
Nsat_tot_3, V_3, Nsh_3 = sat_vth(Vmax_3,Vpeak_3,Vpeak_max,weight_3)
Nsat_tot_4, V_4, Nsh_4 = sat_vth(Vmax_4,Vpeak_4,Vpeak_max,weight_4)
Nsat_tot_5, V_5, Nsh_5 = sat_vth(Vmax_5,Vpeak_5,Vpeak_max,weight_5)
Nsat_tot_6, V_6, Nsh_6 = sat_vth(Vmax_6,Vpeak_6,Vpeak_max,weight_6)
Nsat_tot_7, V_7, Nsh_7 = sat_vth(Vmax_7,Vpeak_7,Vpeak_max,weight_7)
Nsat_tot_8, V_8, Nsh_8 = sat_vth(Vmax_8,Vpeak_8,Vpeak_max,weight_8)


print("Total number of satellites (dz=0.008) = ", int(Nsat_tot_1))
print("Total number of satellites (dz=0.01) = ", int(Nsat_tot_2))
print("Total number of satellites (dz=0.05) = ", int(Nsat_tot_3))
print("Total number of satellites (dz=0.1) = ", int(Nsat_tot_4))
print("Total number of satellites (dz=0.3) = ", int(Nsat_tot_5))
print("Total number of satellites (dz=0.7) = ", int(Nsat_tot_3))
print("Total number of satellites (dz=1.2) = ", int(Nsat_tot_4))
print("Total number of satellites (dz=1.7) = ", int(Nsat_tot_5))
# Out:
# Total number of satellites (dz=0.008) =  17
# Total number of satellites (dz=0.01) =  17
# Total number of satellites (dz=0.05) =  16
# Total number of satellites (dz=0.1) =  15
# Total number of satellites (dz=0.3) =  12
# Total number of satellites (dz=0.7) =  16
# Total number of satellites (dz=1.2) =  15
# Total number of satellites (dz=1.7) =  12

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,6))
ax1.plot(m_1,m2dndm_1)
ax1.plot(m_2,m2dndm_2)
ax1.plot(m_3,m2dndm_3)
ax1.plot(m_4,m2dndm_4)
ax1.plot(m_5,m2dndm_5)
ax1.plot(m_6,m2dndm_6)
ax1.plot(m_7,m2dndm_7)
ax1.plot(m_8,m2dndm_8)
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_title('Mass Function: $M_{host}=10^{ %i } M_{\odot}$' %np.log10(M0),loc='center',fontsize=12)
ax1.set_xlabel(r'$m$ [$M_{\odot}$]',fontsize=20)
ax1.set_ylabel(r'$m^{2} dN_{\rm sh}/dm$ [$M_{\odot}$]',fontsize=20)
#ax1.set_xlim(1,1e2)
ax1.set_ylim(1e4,4e10)

ax2.loglog(V_1,Nsh_1)
ax2.loglog(V_2,Nsh_2)
ax2.loglog(V_3,Nsh_3)
ax2.loglog(V_4,Nsh_4)
ax2.loglog(V_5,Nsh_5)
ax2.loglog(V_6,Nsh_6)
ax2.loglog(V_7,Nsh_7)
ax2.loglog(V_8,Nsh_8)
ax2.set_xlim(1,1e2)
ax2.set_ylim(1e-1,1e3)
ax2.set_title('Satellites: $M_{host}=10^{ %i } M_{\odot}$' %np.log10(M0) + 
              str(r', $V_{peak,max}>$') + str(Vpeak_max),loc='center',fontsize=12)
ax2.set_xlabel(r'$V_{\rm max}$ [km/s]',fontsize=20)
ax2.set_ylabel(r'$N_{\rm sh}(>V_{\rm max})$',fontsize=20)

for ax in (ax1,ax2):
    ax.tick_params(labelsize=12)
    ax.legend(['dz=0.008','dz=0.01','dz=0.05','dz=0.1','dz=0.3','dz=0.7','dz=1.2','dz=1.7'],fontsize=10)
plt.tight_layout()
#plt.savefig('gen_comp_dz_no_spatial.png')

# %%
def slope_1(m0,weight):
    N,lnm_edges = np.histogram(np.log(m0/Msolar),weights=weight,bins=30)
    lnm = (lnm_edges[1:]+lnm_edges[:-1])/2.
    dlnm = lnm_edges[1:]-lnm_edges[:-1]
    dlnm_2 = (dlnm[1:]+dlnm[:-1])/2
    m = np.exp(lnm)
    m_2 = (m[1:]+m[:-1])/2.
    dNdm = N/dlnm/m
    dNdm_2= np.log(dNdm[1:])-np.log(dNdm[:-1])
    return m_2,dNdm_2/dlnm_2

m2_1, a_1 = slope_1(m0_1,weight_1)
m2_2, a_2 = slope_1(m0_2,weight_2)
m2_3, a_3 = slope_1(m0_3,weight_3)
m2_4, a_4 = slope_1(m0_4,weight_4)
m2_5, a_5 = slope_1(m0_5,weight_5)
m2_6, a_6 = slope_1(m0_6,weight_6)
m2_7, a_7 = slope_1(m0_7,weight_7)
m2_8, a_8 = slope_1(m0_8,weight_8)

plt.figure(figsize=(7,7))
plt.plot(m2_1, a_1)
plt.plot(m2_2, a_2)
plt.plot(m2_3, a_3)
plt.plot(m2_4, a_4)
plt.plot(m2_5, a_5)
plt.plot(m2_6, a_6)
plt.plot(m2_7, a_7)
plt.plot(m2_8, a_8)
plt.xlim(1e-5,1e12)
plt.ylim(-2.2,-1.6)
plt.xscale('log')
plt.xlabel(r"$m[M\odot]$")
plt.ylabel("a")
plt.legend(['dz=0.008','dz=0.01','dz=0.05','dz=0.1','dz=0.3','dz=0.7','dz=1.2','dz=1.7'],fontsize=10)
plt.title('Slope: $M_{host}=10^{ %i } M_{\odot}$' %np.log10(M0),loc='center')
plt.tight_layout()
#plt.savefig('slope_dz_comp_no_spatial.png')
plt.show()

# %%
import scipy.integrate as spint
def mass_fraction(mass,weight,Mhost=1e12,evolved=True):
    Mhost=Mhost*Msolar
    if evolved:
        fsh = np.sum(mass*weight)/Mhost
    else:
        fsh = np.sum(mass*weight)/Mhost
    return fsh

def mass_fraction_2(mass,weight,Mhost=M0):
    Mhost=Mhost*Msolar
    N,lnm_edges = np.histogram(np.log(mass/Msolar),weights=weight,bins=100)
    lnm = (lnm_edges[1:]+lnm_edges[:-1])/2.
    dlnm = lnm_edges[1:]-lnm_edges[:-1]
    m = np.exp(lnm)
    dNdm = N/dlnm/m
    
    fsh=spint.simpson(dNdm*m,m)/M0
    return fsh

print(" Weighted Sum Calculation:")
print(" Substructure mass fraction for dz=0.008:",
      mass_fraction(mass=m0_1,weight=weight_1 ,Mhost=M0,evolved=True))


print(" Substructure mass fraction for dz=0.01:",
      mass_fraction(mass=m0_2,weight=weight_2 ,Mhost=M0,evolved=True))

print(" Substructure mass fraction for dz=0.05:",
      mass_fraction(mass=m0_3,weight=weight_3 ,Mhost=M0,evolved=True))

print(" Substructure mass fraction for dz=0.1:",
      mass_fraction(mass=m0_4,weight=weight_4 ,Mhost=M0,evolved=True))

print(" Substructure mass fraction for for dz=0.3:",
      mass_fraction(mass=m0_5,weight=weight_5 ,Mhost=M0,evolved=True))

print(" Substructure mass fraction for dz=0.7:",
      mass_fraction(mass=m0_6,weight=weight_6 ,Mhost=M0,evolved=True))

print(" Substructure mass fraction for for dz=1.2:",
      mass_fraction(mass=m0_7,weight=weight_7 ,Mhost=M0,evolved=True))

print(" Substructure mass fraction for for dz=1.7:",
      mass_fraction(mass=m0_8,weight=weight_8 ,Mhost=M0,evolved=True))


print("\n _________________________________________________________________________________ \n")
print(" Integral Calculation:")
print(" Substructure mass fraction for dz=0.008:",
      mass_fraction_2(mass=m0_1,weight=weight_1 ,Mhost=M0))


print(" Substructure mass fraction for dz=0.01:",
      mass_fraction_2(mass=m0_2,weight=weight_2 ,Mhost=M0))

print(" Substructure mass fraction for dz=0.05:",
      mass_fraction_2(mass=m0_3,weight=weight_3 ,Mhost=M0))

print(" Substructure mass fraction for dz=0.1:",
      mass_fraction_2(mass=m0_4,weight=weight_4 ,Mhost=M0))

print(" Substructure mass fraction for dz=0.3:",
      mass_fraction_2(mass=m0_5,weight=weight_5 ,Mhost=M0))

print(" Substructure mass fraction for dz=0.7:",
      mass_fraction_2(mass=m0_6,weight=weight_6 ,Mhost=M0))

print(" Substructure mass fraction for dz=1.2:",
      mass_fraction_2(mass=m0_7,weight=weight_7 ,Mhost=M0))

print(" Substructure mass fraction for dz=1.7:",
      mass_fraction_2(mass=m0_8,weight=weight_8 ,Mhost=M0))
# Out:
#  Weighted Sum Calculation:
#  Substructure mass fraction for dz=0.008: 0.08941806669122439
#  Substructure mass fraction for dz=0.01: 0.08903518946634006
#  Substructure mass fraction for dz=0.05: 0.08162186380380372
#  Substructure mass fraction for dz=0.1: 0.07291050543741164
#  Substructure mass fraction for for dz=0.3: 0.04475005121762059
#  Substructure mass fraction for dz=0.7: 0.014317918876037531
#  Substructure mass fraction for for dz=1.2: 0.0030453080500980768
#  Substructure mass fraction for for dz=1.7: 0.0005784747445644986
#
#  _________________________________________________________________________________
#
#  Integral Calculation:
#  Substructure mass fraction for dz=0.008: 0.08870111196087921
#  Substructure mass fraction for dz=0.01: 0.08832230248471451
#  Substructure mass fraction for dz=0.05: 0.08070827704955795
#  Substructure mass fraction for dz=0.1: 0.0718283328517095
#  Substructure mass fraction for dz=0.3: 0.04342745203654525
# ...

# %%
fsh1=mass_fraction(mass=m0_1,weight=weight_1)
fsh2=mass_fraction(mass=m0_2,weight=weight_2)
fsh3=mass_fraction(mass=m0_3,weight=weight_3)
fsh4=mass_fraction(mass=m0_4,weight=weight_4)
fsh5=mass_fraction(mass=m0_5,weight=weight_5)
fsh6=mass_fraction(mass=m0_6,weight=weight_6)
fsh7=mass_fraction(mass=m0_7,weight=weight_7)
fsh8=mass_fraction(mass=m0_8,weight=weight_8)

# %%
dz=np.array([0.008,0.01,0.05,0.1,0.3,0.7,1.2,1.7])
fsh=np.array([fsh1,fsh2,fsh3,fsh4,fsh5,fsh6,fsh7,fsh8])
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,6))
for ax in (ax1,ax2):

    ax.scatter(dz[0],fsh1)
    ax.scatter(dz[1],fsh2)
    ax.scatter(dz[2],fsh3)
    ax.scatter(dz[3],fsh4)
    ax.scatter(dz[4],fsh5)
    ax.scatter(dz[5],fsh6)
    ax.scatter(dz[6],fsh7)
    ax.scatter(dz[7],fsh8)
    ax.legend(['dz=0.008','dz=0.01','dz=0.05','dz=0.1','dz=0.3','dz=0.7','dz=1.2','dz=1.7'],fontsize=10)
    ax1.set_title('Mass Function: $M_{host}=10^{ %i } M_{\odot}$' %np.log10(M0),loc='center',fontsize=12)
    ax.set_xlabel(r'$dz$',fontsize=20)
    ax.set_ylabel(r'$\frac{m_{sh,total}}{M_{host}}$',fontsize=20)

ax2.set_xscale('log')
plt.tight_layout()
#plt.savefig('gen_comp_dz_no_spatial.png')

# %%
import scipy.optimize as spopt
import scipy.stats as sps
def fiting(function,x,y,p0):
    ml_cfpars, ml_cfcovar = spopt.curve_fit(function,x,y,p0)
    print("The covariance matrix is: ",ml_cfcovar)
    model_ens = np.linspace(0,1.8,1000)

    fig, (ax1, ax2) = plt.subplots(2,1, figsize=(8,6),sharex=True,gridspec_kw={'height_ratios':[2,1]})
    fig.subplots_adjust(hspace=0)
    y_fit=function(model_ens,*ml_cfpars)
    ax1.set_title(r"Substructure mass fraction for $M_{host}=10^{12} \cdot M_{solar}$", fontsize=12)
    ax1.plot(model_ens, y_fit, lw=2)
    ax1.scatter(x, y)
    ax1.set_xscale('log')
    ax1.set_ylabel(r"$\frac{m_{sh,total}}{M_{host}}$", fontsize=16)
    
    ax2.scatter(x,function(x,*ml_cfpars)/y)
    ax2.set_ylabel("model/data", fontsize=12)
    ax2.set_xlabel("dz (redshift step)",fontsize=12)
    ax2.axhline(1.0, color='r', linestyle='dotted', lw=2)
    ax2.set_ylim(0.8,1.2)
    plt.show()

    print("Model's prediction of mass fraction for dz=0 value",function(0,*ml_cfpars))
    return ml_cfpars

# %%
def pol_2(x,*par):
    return par[2]*x**2+par[1]*x+par[0]

def pol_3(x,*par):
    return par[3]*x**3+par[2]*x**2+par[1]*x+par[0]

# %%
p0=[ 6.00790081e-06,-1.58510599e-05 ,7.64237519e-06]
parameters_3=fiting(pol_2,dz,fsh,p0)
# Out:
# The covariance matrix is:  [[ 6.00790084e-06 -1.58510602e-05  7.64237539e-06]
#  [-1.58510602e-05  1.08883045e-04 -6.42188346e-05]
#  [ 7.64237539e-06 -6.42188346e-05  4.06493754e-05]]
# Model's prediction of mass fraction for dz=0 value 0.08792714270727298

# %%
p0=[4.38004221e-09,-4.94119091e-08,1.23889551e-07,-1.07453002e-07]
par=fiting(pol_3,dz,fsh,p0)
print("f_{sh} (dz) = ",round(par[3],2),"*(dz)^3+",round(par[2],2),
                                    "*(dz)^2+",round(par[1],2),"*(dz)+",round(par[0],4))
# Out:
# The covariance matrix is:  [[ 5.18928500e-08 -3.08359497e-07  3.92537992e-07 -1.35438929e-07]
#  [-3.08359497e-07  4.32722394e-06 -6.51844475e-06  2.41750376e-06]
#  [ 3.92537992e-07 -6.51844475e-06  1.05833061e-05 -4.09595155e-06]
#  [-1.35438929e-07  2.41750376e-06 -4.09595155e-06  1.62748052e-06]]
# Model's prediction of mass fraction for dz=0 value 0.09080636747627047
# f_{sh} (dz) =  -0.03 *(dz)^3+ 0.14 *(dz)^2+ -0.19 *(dz)+ 0.0908
